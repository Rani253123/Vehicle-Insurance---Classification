# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:\\Users\\ranik\\Downloads\\test.csv')
data.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
# removing id and dl
data.drop(['id','Driving_License'], axis=1, inplace=True)

#lets encode the object columns
data['Gender'] = data['Gender'].replace(('Male','Female'),(1, 0))
data['Vehicle_Age'] = data['Vehicle_Age'].replace(('< 1 Year','1-2 Year','> 2 Years'),(0,1,2))
data['Vehicle_Damage'] = data['Vehicle_Damage'].replace(('Yes','No'))

# %%
data.head()
# Out:
#    Gender  Age  Region_Code  Previously_Insured  Vehicle_Age Vehicle_Damage  \
# 0       1   25         11.0                   1            0             No
# 1       1   40         28.0                   0            1             No
# 2       1   47         28.0                   0            1             No
# 3       1   24         27.0                   1            0             No
# 4       1   27         28.0                   1            0             No
#
#    Annual_Premium  Policy_Sales_Channel  Vintage
# 0         35786.0                 152.0       53
# 1         33762.0                   7.0      111
# 2         40050.0                 124.0      199
# 3         37356.0                 152.0      187
# 4         59097.0                 152.0      297

# %%
x = data.iloc[:,:]
x[0:3]
# Out:
#    Gender  Age  Region_Code  Previously_Insured  Vehicle_Age Vehicle_Damage  \
# 0       1   25         11.0                   1            0             No
# 1       1   40         28.0                   0            1             No
# 2       1   47         28.0                   0            1             No
#
#    Annual_Premium  Policy_Sales_Channel  Vintage
# 0         35786.0                 152.0       53
# 1         33762.0                   7.0      111
# 2         40050.0                 124.0      199

# %%
# loading Vehicle_Insurance_classification ml model

import pickle

filename = 'Vehicle_Insurance_classification.sav'
load_model = pickle.load(open(filename , 'rb')) 

from sklearn.preprocessing import StandardScaler
sc = StandardScaler() 
x = sc.fit_transform(x)

y = load_model.predict(x)
y
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[15], line 6
#       3 import pickle
#       5 filename = 'Vehicle_Insurance_classification.sav'
# ----> 6 load_model = pickle.load(open(filename , 'rb'))
#       8 from sklearn.preprocessing import StandardScaler
#       9 sc = StandardScaler()
#
# EOFError: Ran out of input

# %%
score = load_model.score(x, y)
print("score: {0:.2f} %".format(100 * score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 score = load_model.score(x, y)
#       2 print("score: {0:.2f} %".format(100 * score))
#
# NameError: name 'y' is not defined

# %%
import seaborn as sns
sns.countplot(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 import seaborn as sns
# ----> 2 sns.countplot(y)
#
# NameError: name 'y' is not defined

# %%
data['Reponse'] = y.tolist()
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data['Reponse'] = y.tolist()
#       2 data
#
# NameError: name 'y' is not defined

# %%
data[:20]
# Out:
#     Gender  Age  Region_Code  Previously_Insured  Vehicle_Age Vehicle_Damage  \
# 0        1   25         11.0                   1            0             No
# 1        1   40         28.0                   0            1             No
# 2        1   47         28.0                   0            1             No
# 3        1   24         27.0                   1            0             No
# 4        1   27         28.0                   1            0             No
# 5        1   22         30.0                   1            0             No
# 6        0   51         37.0                   1            1             No
# 7        1   25         41.0                   1            0             No
# 8        1   42         41.0                   0            1             No
# 9        0   37         12.0                   1            1             No
# 10       1   40          7.0                   1            1             No
# 11       1   64         28.0                   0            2             No
# 12       0   23         46.0                   1            0             No
# 13       1   47          3.0                   0            1             No
# 14       0   55         48.0                   0            1             No
# 15       1   24         28.0                   1            0             No
# 16       1   25         24.0                   0            0             No
# 17       1   41         10.0                   0            1             No
# 18       1   26         28.0                   1            0             No
# 19       0   28         37.0                   1            0             No
#
#     Annual_Premium  Policy_Sales_Channel  Vintage
# 0          35786.0                 152.0       53
# 1          33762.0                   7.0      111
# 2          40050.0                 124.0      199
# 3          37356.0                 152.0      187
# 4          59097.0                 152.0      297
# 5          40207.0                 152.0      266
# 6          40118.0                  26.0      107
# 7          23375.0                 152.0      232
# 8           2630.0                  26.0      277
# 9          27124.0                 124.0      133
# 10          2630.0                 124.0       91
# 11         32051.0                 124.0      254
# 12         27688.0                  26.0       29
# 13         28739.0                 124.0       22
# 14          2630.0                 124.0      169
# 15         42261.0                  26.0      270
# 16         42660.0                 152.0      207
# 17         15006.0                 124.0      141
# 18         46139.0                 152.0       35
# 19         34907.0                 152.0      293
